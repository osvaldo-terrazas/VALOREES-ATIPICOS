# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos_gastos_costos_2020 = pd.read_csv('GASTOS Y COSTOS 2020 CORREGIDO.csv')
datos_gastos_costos_2020
# Out:
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2020-01-01                   39408
# 1              1  2020-01-01  0001010100750847116902
# 2              2  2020-01-01  0001010100752163714102
# 3              3  2020-01-01                    3663
# 4              4  2020-01-01                    2849
# ...          ...         ...                     ...
# 3337        3337  2020-12-01                  125834
# 3338        3338  2020-12-01                   37652
# 3339        3339  2020-12-01                     160
# 3340        3340  2020-12-01                  634875
# 3341        3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# ...

# %%
datos_gastos_costos_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3342 non-null   int64
#  1   FECHA        3342 non-null   object
#  2   FOLIO        3342 non-null   object
#  3   UUID         3342 non-null   object
#  4   RFC          3342 non-null   object
#  5   PROVEEDOR    3342 non-null   object
#  6   TIPO GASTO   3342 non-null   object
#  7   GASTO        3342 non-null   object
#  8   DESCRIPCION  3342 non-null   object
#  9   TC           3342 non-null   object
#  10  IMPORTE      3342 non-null   float64
#  11  IVA          3342 non-null   float64
#  12  RET ISR      3342 non-null   float64
#  13  RET IVA      3342 non-null   float64
#  14  TOTAL MX     3342 non-null   float64
#  15  TOTAL SAT    3342 non-null   float64
#  16  TIPO         3341 non-null   object
#  17  STATUS       3342 non-null   object
# ...

# %%
columnas_cualitativas = datos_gastos_costos_2020[['Unnamed: 0', 'FECHA', 'FOLIO', 'UUID', 'RFC', 'PROVEEDOR', 'TIPO GASTO', 'GASTO', 'DESCRIPCION', 'TC', 'TIPO', 'STATUS', 'POLIZA', 'Columna1']]

# %%
#Eliminamos columnas innecesarias
#Eliminamos columnas innecesarias
datos_gastos_costos_2020_1 = datos_gastos_costos_2020.drop(['Unnamed: 0', 'FECHA', 'FOLIO', 'UUID', 'RFC', 'PROVEEDOR', 'TIPO GASTO', 'GASTO', 'DESCRIPCION', 'TC', 'TIPO', 'STATUS', 'POLIZA', 'Columna1'], axis = 1)
datos_gastos_costos_2020_1
# Out:
#        IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0         0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1       490.00    78.40      0.0      0.0    568.40     568.40
# 2       195.00    31.20      0.0      0.0    226.20     226.20
# 3     10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4         0.00   519.80      0.0      0.0      0.00       0.00
# ...        ...      ...      ...      ...       ...        ...
# 3337    129.79    20.21      0.0      0.0    150.00     150.00
# 3338   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339    163.79    26.21      0.0      0.0    190.00     190.00
# 3340      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 6 columns]

# %%
#Realizamos diagrama de caja o bigote de cada columna del data frame
fig = plt.figure(figsize = (15, 8))
datos_gastos_costos_2020_1.plot(kind = 'box', vert = False)
plt.title("Valores atipicos del DataFrame")
plt.show()

# %%
y = datos_gastos_costos_2020_1
Limite_superior = y.mean() + 3*y.std()
Limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", Limite_superior)
print("Limite inferior permitido", Limite_inferior)
# Out:
# Limite superior permitido IMPORTE      25167.992859
# IVA           4563.165637
# RET ISR        667.271992
# RET IVA        958.239955
# TOTAL MX     28488.002843
# TOTAL SAT    33250.398514
# dtype: float64
# Limite inferior permitido IMPORTE     -18869.298785
# IVA          -3523.520012
# RET ISR       -627.750813
# RET IVA       -839.215179
# TOTAL MX    -21455.655297
# TOTAL SAT   -25762.462834
# dtype: float64

# %%
gastos_costos_2020_limpio = datos_gastos_costos_2020_1[(y <= Limite_superior) & (y >= Limite_inferior)]
gastos_costos_2020_limpio
# Out:
#        IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0         0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1       490.00    78.40      0.0      0.0    568.40     568.40
# 2       195.00    31.20      0.0      0.0    226.20     226.20
# 3     10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4         0.00   519.80      0.0      0.0      0.00       0.00
# ...        ...      ...      ...      ...       ...        ...
# 3337    129.79    20.21      0.0      0.0    150.00     150.00
# 3338   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339    163.79    26.21      0.0      0.0    190.00     190.00
# 3340      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 6 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos = gastos_costos_2020_limpio.isnull().sum()
valores_nulos
# Out:
# IMPORTE      67
# IVA          58
# RET ISR      21
# RET IVA      74
# TOTAL MX     65
# TOTAL SAT    45
# dtype: int64

# %%
#Reemplazamos valores atipicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
gastos_costos_2020_limpioo = gastos_costos_2020_limpio.copy()
gastos_costos_2020_limpioo = gastos_costos_2020_limpioo.fillna(round(gastos_costos_2020_limpio.mean(), 1))
gastos_costos_2020_limpioo
# Out:
#        IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0         0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1       490.00    78.40      0.0      0.0    568.40     568.40
# 2       195.00    31.20      0.0      0.0    226.20     226.20
# 3     10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4         0.00   519.80      0.0      0.0      0.00       0.00
# ...        ...      ...      ...      ...       ...        ...
# 3337    129.79    20.21      0.0      0.0    150.00     150.00
# 3338   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339    163.79    26.21      0.0      0.0    190.00     190.00
# 3340      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 6 columns]

# %%
valores_nulos_data_clean = gastos_costos_2020_limpioo.isnull().sum()
valores_nulos_data_clean
# Out:
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
gastos_costos_2020_final = pd.concat([gastos_costos_2020_limpioo, columnas_cualitativas], axis=1)
gastos_costos_2020_final
# Out:
#        IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Unnamed: 0  \
# 0         0.00  2248.28      0.0      0.0   2248.28   16300.00           0
# 1       490.00    78.40      0.0      0.0    568.40     568.40           1
# 2       195.00    31.20      0.0      0.0    226.20     226.20           2
# 3     10694.25  1711.08      0.0      0.0  12405.33   12405.33           3
# 4         0.00   519.80      0.0      0.0      0.00       0.00           4
# ...        ...      ...      ...      ...       ...        ...         ...
# 3337    129.79    20.21      0.0      0.0    150.00     150.00        3337
# 3338   2284.80   365.57      0.0      0.0   2650.37    2650.37        3338
# 3339    163.79    26.21      0.0      0.0    190.00     190.00        3339
# 3340      0.00     0.00      0.0      0.0      0.00       0.00        3340
# 3341  14889.29     0.00      0.0      0.0  14889.29   14889.29        3341
#
#            FECHA                   FOLIO  \
# ...

# %%
gastos_costos_2020_final.to_csv("Gastos y costos 2020 Limpio.csv")
